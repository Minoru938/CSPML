# %%
# Load self-defined functions.
# %run tools.ipynb

# Import libraries.
from KmdPlus import StatsDescriptor, formula_to_composition 
import pandas as pd
import numpy as np
from statistics import median
from scipy.spatial import distance_matrix
from pymatgen.core.composition import Composition
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import time
import pickle
import math
import os
from keras import backend as K
from keras.layers import Layer
from keras import regularizers
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, BatchNormalization, Activation
from tensorflow.keras.layers import Input, Dropout
import random
import optuna
# from mp_api import MPRester
from matminer.featurizers.site import CrystalNNFingerprint  
from matminer.featurizers.structure import SiteStatsFingerprint
import itertools
from collections import Counter
import copy

# Loading MLdata (run CSPML_Creating_MLdata.ipynb for creating CSPML_MLdata.xz).
with open("data_set/CSPML_MLdata.xz", "rb") as f:
    MLdata = pickle.load(f)

# %%
# Data for the hyper-parameter optimization.
i = 0

train_X, train_y = MLdata[i]["train_set"]["X"], to_categorical(MLdata[i]["train_set"]["y"])
val_X, val_y = MLdata[i]["val_set"]["X"], to_categorical(MLdata[i]["val_set"]["y"])
test_X, test_y = MLdata[i]["test_set"]["X"], to_categorical(MLdata[i]["test_set"]["y"])

# Function for making model structure (classifier).
def Make_MLP_model(Layer_num, Unit_num, Drop_out, Input_shape):
    K.clear_session()
    input = Input(shape=(Input_shape,))
    x = Dense(Unit_num)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(Drop_out)(x)
    
    for i in range(Layer_num-2):
        x = Dense(Unit_num)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(Drop_out)(x)
    
    x = Dense(Unit_num)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dense(2)(x) # for classifier.
    x = Activation('softmax')(x) # for classifier.
    model = Model(input, x)
    return model

# %%
###### Hyper parameter optimization #####

start = time.time()

# Set seed for whole loops.
tf.keras.utils.set_random_seed(1122)

# Set the fixed hyperparameters.
verbose = 0
epochs = 1000
n_trials = 50

# Define optuna function.
def objective(trial):

    # Set region of hyperparameters.
    Drop_out = trial.suggest_float('Drop_out', 0, 0.2, step = 0.1)
    Unit_num = trial.suggest_int('Unit_num', 200, 1000, 200)
    Layer_num = trial.suggest_int('Layer_num', 2, 4, 1)
    patience = trial.suggest_int('patience', 50, 100, 25)
    batch_size = trial.suggest_categorical('batch_size', [1024, 2048])
    
    # Create model.
    model = Make_MLP_model(Layer_num, Unit_num, Drop_out, train_X.shape[1])
    model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=['accuracy'])

    # Set callback.
    early_stopping = EarlyStopping(monitor='val_accuracy', patience = patience, verbose = verbose, mode='max')
    mcp_save = ModelCheckpoint('model.hdf5',verbose = verbose, save_best_only=True, monitor='val_accuracy', mode='max')

    # Run model.
    H = model.fit(train_X,train_y,batch_size=batch_size,epochs=epochs,verbose=verbose,validation_data=(val_X, val_y),
                  callbacks=[early_stopping, mcp_save])

    # Load model.
    model.load_weights('model.hdf5')

    # Evaluation of model.
    y_pred = model.predict(val_X, verbose=0)[:,1] 
    y_true = val_y[:,1]
    acc = 1 - np.sum(np.abs(y_true - (y_pred >= 0.5)))/len(y_pred) 

    return acc

# Run optuna for hyper-parameter optimization.
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=42), direction='maximize') # Set seed.
study.optimize(objective, n_trials=n_trials)

end = time.time()
print(f"Calculation time: {end-start} s")

# Save optuna results.
with open("data_set/CSPML_study.xz", "wb") as f:
    pickle.dump(study, f)
# Out:
# [I 2023-12-10 17:36:52,705] A new study created in memory with name: no-name-3f9537a3-90a4-43ee-9713-aa28e4aa4c3a
# 2023-12-10 17:36:52.721111: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-12-10 17:36:52.721337: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Max
# 2023-12-10 17:36:53.326847: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-12-10 17:36:53.828234: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:36:58.336916: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:39:28.420430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:39:29,387] Trial 0 finished with value: 0.8467614533965244 and parameters: {'Drop_out': 0.1, 'Unit_num': 1000, 'Layer_num': 4, 'patience': 75, 'batch_size': 1024}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:39:30.111846: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:39:31.608288: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:41:53.330472: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:41:54,041] Trial 1 finished with value: 0.8375084631008802 and parameters: {'Drop_out': 0.0, 'Unit_num': 1000, 'Layer_num': 3, 'patience': 100, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:41:54.520384: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:41:55.685891: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:42:35.609750: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:42:36,303] Trial 2 finished with value: 0.8460844053261115 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 2, 'patience': 50, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:42:36.826693: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:42:38.116839: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:43:43.344391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:43:44,035] Trial 3 finished with value: 0.8441661024599413 and parameters: {'Drop_out': 0.1, 'Unit_num': 400, 'Layer_num': 3, 'patience': 50, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:43:44.639353: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:43:46.192168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:45:04.818532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:45:05,431] Trial 4 finished with value: 0.8441661024599413 and parameters: {'Drop_out': 0.1, 'Unit_num': 800, 'Layer_num': 2, 'patience': 75, 'batch_size': 1024}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:45:05.878612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:45:07.691280: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:47:47.873712: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:47:48,520] Trial 5 finished with value: 0.8436018957345972 and parameters: {'Drop_out': 0.1, 'Unit_num': 200, 'Layer_num': 2, 'patience': 100, 'batch_size': 1024}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:47:49.090885: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:47:50.734467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:48:40.095277: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:48:40,971] Trial 6 finished with value: 0.8285939968404423 and parameters: {'Drop_out': 0.0, 'Unit_num': 200, 'Layer_num': 4, 'patience': 75, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:48:41.439389: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:48:42.884768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:49:32.821194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:49:33,426] Trial 7 finished with value: 0.8441661024599413 and parameters: {'Drop_out': 0.0, 'Unit_num': 1000, 'Layer_num': 2, 'patience': 75, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:49:34.029777: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:49:36.530535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:53:29.888440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:53:30,756] Trial 8 finished with value: 0.8445046264951478 and parameters: {'Drop_out': 0.1, 'Unit_num': 200, 'Layer_num': 4, 'patience': 100, 'batch_size': 1024}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:53:31.243495: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:53:32.605859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:54:22.300873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:54:22,943] Trial 9 finished with value: 0.8415707515233581 and parameters: {'Drop_out': 0.1, 'Unit_num': 1000, 'Layer_num': 2, 'patience': 50, 'batch_size': 2048}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:54:23.688745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:54:26.580162: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:56:55.063963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:56:55,979] Trial 10 finished with value: 0.8459715639810427 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 4, 'patience': 75, 'batch_size': 1024}. Best is trial 0 with value: 0.8467614533965244.
# 2023-12-10 17:56:56.561804: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:56:59.056004: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:58:37.502088: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 17:58:38,336] Trial 11 finished with value: 0.8493568043331077 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 17:58:38.879015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 17:58:41.438060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:00:02.662756: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:00:03,499] Trial 12 finished with value: 0.8472128187767998 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:00:04.182077: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:00:06.901960: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:01:47.260945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:01:48,091] Trial 13 finished with value: 0.8451816745655608 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:01:48.634257: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:01:51.436647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:03:16.562977: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:03:17,353] Trial 14 finished with value: 0.8438275784247349 and parameters: {'Drop_out': 0.2, 'Unit_num': 800, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:03:17.904646: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:03:20.693768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:05:05.624401: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:05:06,407] Trial 15 finished with value: 0.8446174678402166 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:05:07.082729: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:05:09.874817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:06:31.623782: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:06:32,419] Trial 16 finished with value: 0.8456330399458362 and parameters: {'Drop_out': 0.2, 'Unit_num': 800, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:06:32.968554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:06:35.705289: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:08:04.442476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:08:05,265] Trial 17 finished with value: 0.8434890543895284 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:08:05.900196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:08:09.452419: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:10:26.068556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:10:26,976] Trial 18 finished with value: 0.8447303091852855 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 4, 'patience': 75, 'batch_size': 1024}. Best is trial 11 with value: 0.8493568043331077.
# 2023-12-10 18:10:27.689282: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:10:30.364284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:12:06.814174: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:12:07,578] Trial 19 finished with value: 0.8513879485443466 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:12:08.125672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:12:10.849622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:13:26.102715: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:13:26,875] Trial 20 finished with value: 0.846422929361318 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:13:27.422501: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:13:30.797819: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:14:41.368138: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:14:42,146] Trial 21 finished with value: 0.8456330399458362 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:14:42.696910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:14:45.782651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:16:40.650245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:16:41,538] Trial 22 finished with value: 0.8422477995937712 and parameters: {'Drop_out': 0.2, 'Unit_num': 800, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:16:42.091870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:16:45.454000: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:18:09.107402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:18:10,006] Trial 23 finished with value: 0.8467614533965244 and parameters: {'Drop_out': 0.2, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:18:10.563621: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:18:14.370840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:19:28.956466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:19:29,873] Trial 24 finished with value: 0.8432633716993907 and parameters: {'Drop_out': 0.1, 'Unit_num': 600, 'Layer_num': 3, 'patience': 50, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:19:30.434827: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:19:34.244194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:21:29.859032: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:21:30,738] Trial 25 finished with value: 0.8482283908824193 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 75, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:21:31.200201: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:21:34.080223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:23:45.112745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:23:45,883] Trial 26 finished with value: 0.8441661024599413 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 2, 'patience': 100, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:23:46.487964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:23:51.296517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:26:06.774630: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:26:07,852] Trial 27 finished with value: 0.8438275784247349 and parameters: {'Drop_out': 0.1, 'Unit_num': 200, 'Layer_num': 4, 'patience': 75, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:26:08.436725: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:26:12.247147: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:27:48.553118: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:27:49,440] Trial 28 finished with value: 0.8429248476641842 and parameters: {'Drop_out': 0.2, 'Unit_num': 400, 'Layer_num': 3, 'patience': 75, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:27:50.083560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:27:54.854307: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:29:44.864310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:29:45,936] Trial 29 finished with value: 0.8456330399458362 and parameters: {'Drop_out': 0.1, 'Unit_num': 400, 'Layer_num': 4, 'patience': 75, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18:29:46.658993: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:29:50.609910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 18:32:08.061951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [I 2023-12-10 18:32:09,017] Trial 30 finished with value: 0.8433762130444595 and parameters: {'Drop_out': 0.2, 'Unit_num': 200, 'Layer_num': 3, 'patience': 100, 'batch_size': 1024}. Best is trial 19 with value: 0.8513879485443466.
# 2023-12-10 18
# 31 0 days 00:01:34.165470              0.2                 3              600
# 32 0 days 00:01:14.529569              0.2                 3              600
# 33 0 days 00:01:30.848141              0.2                 3              400
# 34 0 days 00:00:52.082389              0.2                 3              800
# 35 0 days 00:02:19.395306              0.2                 3              400
# 36 0 days 00:00:50.815227              0.2                 2              600
# 37 0 days 00:01:23.967956              0.0                 3              400
# 38 0 days 00:01:09.466577              0.1                 2              800
# 39 0 days 00:01:29.396154              0.1                 3              200
# 40 0 days 00:02:09.483087              0.2                 4              600
# 41 0 days 00:01:20.722730              0.2                 3              600
# 42 0 days 00:01:20.031033              0.2                 3              600
# 43 0 days 00:01:26.135824              0.2                 3              600
# 44 0 days 00:01:17.898770              0.2                 3              400
# 45 0 days 00:01:05.238912              0.2                 3              800
# 46 0 days 00:01:26.481304              0.2                 3              600
# 47 0 days 00:00:56.239347              0.2                 2              600
# 48 0 days 00:01:20.029620              0.2                 3              600
# 49 0 days 00:01:14.538483              0.0                 3              800
#
#     params_batch_size  params_patience     state
# 0                1024               75  COMPLETE
# 1                2048              100  COMPLETE
# 2                2048               50  COMPLETE
# 3                2048               50  COMPLETE
# 4                1024               75  COMPLETE
# 5                1024              100  COMPLETE
# 6                2048               75  COMPLETE
# 7                2048               75  COMPLETE
# 8                1024              100  COMPLETE
# 9                2048               50  COMPLETE
# 10               1024               75  COMPLETE
# 11               1024               50  COMPLETE
# 12               1024               50  COMPLETE
# 13               1024               50  COMPLETE
# 14               1024               50  COMPLETE
# 15               1024               50  COMPLETE
# 16               1024               50  COMPLETE
# 17               1024               50  COMPLETE
# 18               1024               75  COMPLETE
# 19               1024               50  COMPLETE
# 20               1024               50  COMPLETE
# 21               1024               50  COMPLETE
# 22               1024               50  COMPLETE
# 23               1024               50  COMPLETE
# 24               1024               50  COMPLETE
# 25               1024               75  COMPLETE
# 26               1024              100  COMPLETE
# 27               1024               75  COMPLETE
# 28               1024               75  COMPLETE
# 29               1024               75  COMPLETE
# 30               1024              100  COMPLETE
# 31               1024               50  COMPLETE
# 32               1024               50  COMPLETE
# 33               1024               50  COMPLETE
# 34               2048               50  COMPLETE
# 35               1024               75  COMPLETE
# 36               2048               50  COMPLETE
# 37               1024               75  COMPLETE
# 38               2048              100  COMPLETE
# 39               1024               50  COMPLETE
# 40               1024               75  COMPLETE
# 41               1024               50  COMPLETE
# 42               1024               50  COMPLETE
# 43               1024               50  COMPLETE
# 44               1024               50  COMPLETE
# 45               2048               50  COMPLETE
# 46               1024               50  COMPLETE
# 47               1024               50  COMPLETE
# 48               1024               50  COMPLETE
# 49               2048               50  COMPLETE

# %%
### Training ensemble models with the chosen parameters.

# Set best hyperparameters chosen by optuna studies.
Drop_out = study.best_trial.params['Drop_out']
Unit_num = study.best_trial.params['Unit_num']
Layer_num = study.best_trial.params['Layer_num']
patience = study.best_trial.params['patience']
batch_size = study.best_trial.params['batch_size']

print(f"Layer_num: {Layer_num}")
print(f"Unit_num: {Unit_num}")
print(f"Drop_out: {Drop_out}")
print(f"patience: {patience}")
print(f"batch_size: {batch_size}")

start = time.time()

# Set seed for whole loops.
tf.keras.utils.set_random_seed(1122)

models = []

for i in range(len(MLdata)):
    # Get data.
    train_X, train_y = MLdata[i]["train_set"]["X"], to_categorical(MLdata[i]["train_set"]["y"])
    val_X, val_y = MLdata[i]["val_set"]["X"], to_categorical(MLdata[i]["val_set"]["y"])
    test_X, test_y = MLdata[i]["test_set"]["X"], to_categorical(MLdata[i]["test_set"]["y"])
    
    # Create model.
    model = Make_MLP_model(Layer_num, Unit_num, Drop_out, train_X.shape[1])
    model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=['accuracy'])

    # Set callback.
    early_stopping = EarlyStopping(monitor='val_accuracy', patience = patience, verbose = verbose, mode='max')
    mcp_save = ModelCheckpoint('model.hdf5',verbose = verbose, save_best_only=True, monitor='val_accuracy', mode='max')

    # Run model.
    H = model.fit(train_X,train_y,batch_size=batch_size,epochs=epochs,verbose=verbose,validation_data=(val_X, val_y),
                  callbacks=[early_stopping, mcp_save])

    # Load model.
    model.load_weights('model.hdf5')

    # Evaluation of model.
    y_pred = model.predict(val_X, verbose=0)[:,1] 
    y_true = val_y[:,1]
    acc = 1 - np.sum(np.abs(y_true - (y_pred >= 0.5)))/len(y_pred) 
    print(acc)
    
    models.append(model)

end = time.time()
print(f"Calculation time: {end-start} s")

# Save models.
with open("data_set/CSPML_models.xz", "wb") as f:
    pickle.dump(models, f)
# Out:
# Layer_num: 3
# Unit_num: 400
# Drop_out: 0.2
# patience: 50
# batch_size: 1024
# 2023-12-10 19:16:27.242745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:16:32.788346: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:17:58.221345: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0.8461972466711803
# 2023-12-10 19:17:59.898576: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:18:05.138838: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:19:30.672033: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0.866984505363528
# 2023-12-10 19:19:32.380630: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:19:37.868924: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:21:08.601515: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0.8672270842929526
# 2023-12-10 19:21:10.375350: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:21:15.937503: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:22:52.157661: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0.8543735790355391
# 2023-12-10 19:22:53.888135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:22:59.497223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:24:41.468894: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 0.8579929053667468
# Calculation time: 496.0056710243225 s
# INFO:tensorflow:Assets written to: ram://2d9f1e72-62dd-43db-ab64-0ac98a0c3eee/assets
# INFO:tensorflow:Assets written to: ram://d25683a6-30d3-469d-a74e-49487d369e8d/assets
# INFO:tensorflow:Assets written to: ram://7a9515e6-d479-4f25-a173-3b3735e4e96e/assets
# INFO:tensorflow:Assets written to: ram://4c92d5a8-75ff-47cc-9e6b-c738a790fa92/assets
# INFO:tensorflow:Assets written to: ram://61cd304e-e24a-4f73-857b-b7595e1232a6/assets

# %%
# For evaluating model performance.
from sklearn.metrics import average_precision_score, accuracy_score

os.makedirs("ML_metrics")

# Calculate per-class Metrics.

list_APs = []
list_accs = []

for i in range(len(MLdata)):
    # Get ratio labels.
    ratio_class = copy.deepcopy(MLdata[i]["test_set"]["y_class"]) # Test class label (ith).
    # Get couters and unique labels.
    count = Counter(ratio_class).most_common()
    ratio_class_unique = np.array([count[i][0] for i in range(len(count))], dtype = "object")
    freqs = np.array([count[i][1] for i in range(len(count))])
    # Get test set.
    test_X, test_y = MLdata[i]["test_set"]["X"], MLdata[i]["test_set"]["y"]
    # Calculate per class metrics.
    APs = []
    accs = []
    for j in range(len(ratio_class_unique)):
        ix = (ratio_class == ratio_class_unique[j])
        y_pred = models[i].predict(test_X[ix], verbose=0)[:,1]
        y_true = test_y[ix]
        accs.append(accuracy_score(y_true, (y_pred >= 0.5)*1)) # accuracy is ok for in case len(y_true) = 1 or 
                                                               # len(np.unique(y_true)) = 1.
        if len(np.unique(y_true)) < 2: # in case AP is meaningless (since always 1).
            pass
        else:
            APs.append(average_precision_score(y_true, y_pred))
           
    APs = np.array(APs)
    accs = np.array(accs)
    
    # Save plot.
    fig = plt.figure(figsize=(16,4))
    plt.bar(np.arange(len(APs)), APs)
    plt.title(f"Per class average precisions for {i+1}th test set; MAP = {np.mean(APs):.3f}")
    plt.xlabel(f"Ratio labels")
    plt.ylabel("Average precisions")
    fig.tight_layout()
    plt.savefig(f"ML_metrics/Per class average precisions for {i+1}th test set.png", dpi = 100)
    plt.close()
    
    fig = plt.figure(figsize=(16,4))
    plt.bar(np.arange(len(accs)), accs)
    plt.title(f"Per class accuracies for {i+1}th test set; MACC={np.mean(accs):.3f}")
    plt.xlabel(f"Ratio labels")
    plt.ylabel("Accuracies")
    fig.tight_layout()
    plt.savefig(f"ML_metrics/Per class accuracies for {i+1}th test set.png", dpi = 100)
    plt.close()
    
    fig = plt.figure(figsize=(16,4))
    plt.bar(np.arange(len(accs)), freqs, log=True)
    plt.title(f"Distribution of the ratio labels for {i+1}th test set")
    plt.xlabel(f"Ratio labels")
    plt.ylabel("Number of ratio labels")
    fig.tight_layout()
    plt.savefig(f"ML_metrics/Distribution of the ratio labels for {i+1}th test set.png", dpi = 100)
    plt.close()
    
    list_APs.append(APs)
    list_accs.append(accs)
    
# Get MAPs and MACCs.
MAPs = np.array([np.mean(list_APs[i]) for i in range(len(MLdata))])
MACCs = np.array([np.mean(list_accs[i]) for i in range(len(MLdata))])

# Not per class APs and Accs.
APs, accs = [], []

for i in range(len(MLdata)):
    # Get test set.
    test_X, test_y = MLdata[i]["test_set"]["X"], MLdata[i]["test_set"]["y"]
    # Make prediction.
    y_pred = models[i].predict(test_X, verbose=0)[:,1]
    y_true = test_y
    APs.append(average_precision_score(y_true, y_pred))
    accs.append(accuracy_score(y_true, (y_pred >= 0.5)*1))
    
APs = np.array(APs)
accs = np.array(accs)
# Out:
# 2023-12-10 19:57:33.164871: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:57:42.626749: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-12-10 19:57:51.547809: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
# Summarize results.
metric_mean = np.array([np.mean(MAPs), np.mean(MACCs), np.mean(APs), np.mean(accs)])
metric_std = np.array([np.std(MAPs), np.std(MACCs), np.std(APs), np.std(accs)])

from tabulate import tabulate

summary = np.round(np.array([metric_mean, metric_std]), 3)

print(tabulate(summary, headers = ["MAP", "MACC", "AP", "ACC"], showindex= ["Mean", "Std"]))
# Out:
#         MAP    MACC     AP    ACC
# ----  -----  ------  -----  -----
# Mean  0.941   0.89   0.913  0.864
# Std   0.007   0.007  0.009  0.011
